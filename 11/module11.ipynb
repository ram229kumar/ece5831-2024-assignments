# %% [markdown]
# ## Binary Classification - IMDB

# %%
import numpy as np
from keras.datasets import imdb
from imdb import Imdb

# %%
imdb_obj = Imdb()

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=imdb_obj.DIMENSIONS)

# %%
x_train = imdb_obj.prepare_data(x_train)
x_test = imdb_obj.prepare_data(x_test)

# %%
model = imdb_obj.build_model()

# %%
history = imdb_obj.train(x_train, y_train)
# Out:
# Epoch 1/20
# 40/40 [==============================] - 3s 66ms/step - loss: 0.5258 - accuracy: 0.7739 - val_loss: 0.3759 - val_accuracy: 0.8758
# Epoch 2/20
# 40/40 [==============================] - 0s 12ms/step - loss: 0.3076 - accuracy: 0.8945 - val_loss: 0.3096 - val_accuracy: 0.8806
# Epoch 3/20
# 40/40 [==============================] - 1s 13ms/step - loss: 0.2319 - accuracy: 0.9186 - val_loss: 0.3331 - val_accuracy: 0.8644
# Epoch 4/20
# 40/40 [==============================] - 1s 13ms/step - loss: 0.1930 - accuracy: 0.9319 - val_loss: 0.2709 - val_accuracy: 0.8924
# Epoch 5/20
# 40/40 [==============================] - 1s 13ms/step - loss: 0.1668 - accuracy: 0.9420 - val_loss: 0.2829 - val_accuracy: 0.8904
# Epoch 6/20
# 40/40 [==============================] - 0s 12ms/step - loss: 0.1458 - accuracy: 0.9506 - val_loss: 0.3102 - val_accuracy: 0.8804

# %%
imdb_obj.plot_loss(history)

# %%
imdb_obj.plot_accuracy(history)

# %%
test_loss, test_accuracy = imdb_obj.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3409 - accuracy: 0.8668
# Test Loss: 0.3409
# Test Accuracy: 0.8668

# %%
print("\nPrediction Example:")
imdb_obj.predict(model, x_test[0], y_test[0])
# Out:
# Prediction Example:
# 1/1 [==============================] - 0s 250ms/step
# True Class:  negative  Predicted Class:  negative

# %% [markdown]
# ## Multiclass Classification - Reuters

# %%
from reuters import Reuters
from keras.datasets import reuters
from keras.utils import to_categorical

# %%
reuters_obj = Reuters()

# %%
(x_train, y_train), (x_test, y_test) = reuters.load_data(num_words=reuters_obj.DIMENSIONS)

# %%
x_train = reuters_obj.prepare_data(x_train)
x_test = reuters_obj.prepare_data(x_test)

# %%
model = reuters_obj.build_model()

# %%
history = reuters_obj.train(x_train, y_train)
# Out:
# Epoch 1/20
# 15/15 [==============================] - 1s 49ms/step - loss: 2.8679 - accuracy: 0.4884 - val_loss: 1.9613 - val_accuracy: 0.5504
# Epoch 2/20
# 15/15 [==============================] - 0s 28ms/step - loss: 1.6400 - accuracy: 0.6508 - val_loss: 1.4769 - val_accuracy: 0.6873
# Epoch 3/20
# 15/15 [==============================] - 0s 28ms/step - loss: 1.2480 - accuracy: 0.7331 - val_loss: 1.2757 - val_accuracy: 0.7134
# Epoch 4/20
# 15/15 [==============================] - 1s 43ms/step - loss: 1.0183 - accuracy: 0.7801 - val_loss: 1.1519 - val_accuracy: 0.7457
# Epoch 5/20
# 15/15 [==============================] - 0s 27ms/step - loss: 0.8520 - accuracy: 0.8161 - val_loss: 1.0984 - val_accuracy: 0.7613
# Epoch 6/20
# 15/15 [==============================] - 0s 25ms/step - loss: 0.7145 - accuracy: 0.8484 - val_loss: 1.0108 - val_accuracy: 0.7841
# Epoch 7/20
# 15/15 [==============================] - 0s 19ms/step - loss: 0.5986 - accuracy: 0.8736 - val_loss: 1.0143 - val_accuracy: 0.7830
# Epoch 8/20
# 15/15 [==============================] - 0s 20ms/step - loss: 0.5106 - accuracy: 0.8931 - val_loss: 1.0723 - val_accuracy: 0.7418

# %%
reuters_obj.plot_loss(history)

# %%
reuters_obj.plot_accuracy(history)

# %%
test_loss, test_accuracy = reuters_obj.evaluate(x_test, to_categorical(y_test, num_classes=reuters_obj.NUM_CLASSES))
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0918 - accuracy: 0.7404
# Test Loss: 1.0918254852294922
# Test Accuracy: 0.7404274344444275

# %%
sample_index = 0  # Change this to test different samples
sample_input = x_test[sample_index]
sample_label = y_test[sample_index]

# Predict the class of the sample
prediction = model.predict(np.expand_dims(sample_input, axis=0))
predicted_class = np.argmax(prediction[0])
true_class = sample_label

print(f"True Class: {true_class}, Predicted Class: {predicted_class}")
# Out:
# WARNING:tensorflow:5 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000239CC699580> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 59ms/step
# True Class: 3, Predicted Class: 3

# %%
print(x_test[0].shape)
print(x_test.shape)
# Out:
# (10000,)
# (2246, 10000)

# %%
reuters_obj.predict(x_test[0],y_test[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 reuters_obj.predict(x_test[0],y_test[0])
#
# File r:\University_of_Michigan_Dearborn\Fall_2024\ECE-5831-Pattern_Recognition_and_Neural_Networkds-Online\ece5831-2024\11\reuters.py:73, in Reuters.predict(self, x_test, y_test)
#      71 def predict(self, x_test, y_test):
#      72     x_test = np.expand_dims(x_test, axis=0)
# ---> 73     prediction = self.model.predict(np.expand_dims(x_test, axis=0))
#      74     predicted_class = np.argmax(prediction[0])
#      75     true_class = y_test
#
# File c:\Users\ramku\anaconda3\envs\teachable-python-ece5831-2024\Lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filebagzt5r2.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# TypeError: in user code:
#
#     File "c:\Users\ramku\anaconda3\envs\teachable-python-ece5831-2024\Lib\site-packages\keras\engine\training.py", line 2169, in predict_function  *
#         return step_function(self, iterator)
#     File "c:\Users\ramku\anaconda3\envs\teachable-python-ece5831-2024\Lib\site-packages\keras\engine\training.py", line 2155, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\ramku\anaconda3\envs\teachable-python-ece5831-2024\Lib\site-packages\keras\engine\training.py", line 2143, in run_step  **
#         outputs = model.predict_step(data)
#     File "c:\Users\ramku\anaconda3\envs\teachable-python-ece5831-2024\Lib\site-packages\keras\engine\training.py", line 2111, in predict_step
#         return self(x, training=False)
#     File "c:\Users\ramku\anaconda3\envs\teachable-python-ece5831-2024\Lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "c:\Users\ramku\anaconda3\envs\teachable-python-ece5831-2024\Lib\site-packages\keras\activations.py", line 83, in softmax
#         if x.shape.rank > 1:
#
#     TypeError: Exception encountered when calling layer 'dense_29' (type Dense).
#
#     '>' not supported between instances of 'NoneType' and 'int'
#
#     Call arguments received by layer 'dense_29' (type Dense):
#       • inputs=tf.Tensor(shape=<unknown>, dtype=float32)
